# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyasriAmalapurapu/Navyasri/blob/main/movies_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('/content/movies.csv')

# %%
data
# Out:
#       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0      id                         title  \
# 0           0   19404   Dilwale Dulhania Le Jayenge
# 1           1  724089     Gabriel's Inferno Part II
# 2           2     278      The Shawshank Redemption
# 3           3     238                 The Godfather
# 4           4  761053    Gabriel's Inferno Part III
# 5           5  696374             Gabriel's Inferno
# 6           6  791373  Zack Snyder's Justice League
# 7           7  399566             Godzilla vs. Kong
# 8           8  441130                   Wolfwalkers
# 9           9     424              Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.433
# 1  Professor Gabriel Emerson finally learns the t...   2020-07-31       8.439
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      65.570
# ...

# %%
data.tail(10)
# Out:
#       Unnamed: 0      id                          title  \
# 8541        8541    9544                     FearDotCom
# 8542        8542  485774                 The Open House
# 8543        8543   35885                       Amore 14
# 8544        8544   12142              Alone in the Dark
# 8545        8545   74849  The Star Wars Holiday Special
# 8546        8546   13805                 Disaster Movie
# 8547        8547    5491              Battlefield Earth
# 8548        8548   14164           Dragonball Evolution
# 8549        8549   11059              House of the Dead
# 8550        8550   40016     Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 8541  When four bodies are discovered among the indu...   2002-08-09
# 8542  A teenager and his mother find themselves besi...   2018-01-19
# 8543  Come ogni 14enne Carolina, detta Caro,è impegn...   2009-10-30
# ...

# %%
data.add
# Out:
# <bound method DataFrame.add of       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
data.all
# Out:
# <bound method DataFrame.all of       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
data.align
# Out:
# <bound method NDFrame.align of       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8551 entries, 0 to 8550
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8551 non-null   int64
#  1   id            8551 non-null   int64
#  2   title         8551 non-null   object
#  3   overview      8531 non-null   object
#  4   release_date  8551 non-null   object
#  5   popularity    8551 non-null   float64
#  6   vote_average  8551 non-null   float64
#  7   vote_count    8551 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 534.6+ KB

# %%
data.isnull()
# Out:
#       Unnamed: 0     id  title  overview  release_date  popularity  \
# 0          False  False  False     False         False       False
# 1          False  False  False     False         False       False
# 2          False  False  False     False         False       False
# 3          False  False  False     False         False       False
# 4          False  False  False     False         False       False
# ...          ...    ...    ...       ...           ...         ...
# 8546       False  False  False     False         False       False
# 8547       False  False  False     False         False       False
# 8548       False  False  False     False         False       False
# 8549       False  False  False     False         False       False
# 8550       False  False  False     False         False       False
#
#       vote_average  vote_count
# 0            False       False
# 1            False       False
# 2            False       False
# 3            False       False
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# title            0
# overview        20
# release_date     0
# popularity       0
# vote_average     0
# vote_count       0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8546    False
# 8547    False
# 8548    False
# 8549    False
# 8550    False
# Length: 8551, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (8551, 8)

# %%
data.size
# Out:
# 68408

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# title            object
# overview         object
# release_date     object
# popularity      float64
# vote_average    float64
# vote_count        int64
# dtype: object

# %%
data.drop('release_date',axis=1,inplace=True)

# %%
data.drop('popularity',axis=1)
# Out:
#       Unnamed: 0      id                        title  \
# 0              0   19404  Dilwale Dulhania Le Jayenge
# 1              1  724089    Gabriel's Inferno Part II
# 2              2     278     The Shawshank Redemption
# 3              3     238                The Godfather
# 4              4  761053   Gabriel's Inferno Part III
# ...          ...     ...                          ...
# 8546        8546   13805               Disaster Movie
# 8547        8547    5491            Battlefield Earth
# 8548        8548   14164         Dragonball Evolution
# 8549        8549   11059            House of the Dead
# 8550        8550   40016   Birdemic: Shock and Terror
#
#                                                overview  vote_average  \
# 0     Raj is a rich, carefree, happy-go-lucky second...           8.7
# 1     Professor Gabriel Emerson finally learns the t...           8.7
# 2     Framed in the 1940s for the double murder of h...           8.7
# ...

# %%
row = data.loc[2]
print(row)
# Out:
# Unnamed: 0                                                      2
# id                                                            278
# title                                    The Shawshank Redemption
# overview        Framed in the 1940s for the double murder of h...
# popularity                                                  65.57
# vote_average                                                  8.7
# vote_count                                                  18637
# Name: 2, dtype: object

# %%
row = data.iloc[2]
print(row)
# Out:
# Unnamed: 0                                                      2
# id                                                            278
# title                                    The Shawshank Redemption
# overview        Framed in the 1940s for the double murder of h...
# popularity                                                  65.57
# vote_average                                                  8.7
# vote_count                                                  18637
# Name: 2, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 sns.heatmap
# Out:
# <function seaborn.matrix.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)>
