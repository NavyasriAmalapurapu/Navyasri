# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyasriAmalapurapu/Navyasri/blob/main/covid_19_dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/WHO-COVID-19-global-data[1].csv')

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 323263    2023-09-23           ZW     Zimbabwe       AFRO          0
# 323264    2023-09-24           ZW     Zimbabwe       AFRO          0
# 323265    2023-09-25           ZW     Zimbabwe       AFRO          0
# 323266    2023-09-26           ZW     Zimbabwe       AFRO          0
# 323267    2023-09-27           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
# 5    2020-01-08           AF  Afghanistan       EMRO          0
# 6    2020-01-09           AF  Afghanistan       EMRO          0
# 7    2020-01-10           AF  Afghanistan       EMRO          0
# 8    2020-01-11           AF  Afghanistan       EMRO          0
# 9    2020-01-12           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# ...

# %%
df.tail(10)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 323258    2023-09-18           ZW  Zimbabwe       AFRO          0
# 323259    2023-09-19           ZW  Zimbabwe       AFRO          0
# 323260    2023-09-20           ZW  Zimbabwe       AFRO          0
# 323261    2023-09-21           ZW  Zimbabwe       AFRO          0
# 323262    2023-09-22           ZW  Zimbabwe       AFRO          0
# 323263    2023-09-23           ZW  Zimbabwe       AFRO          0
# 323264    2023-09-24           ZW  Zimbabwe       AFRO          0
# 323265    2023-09-25           ZW  Zimbabwe       AFRO          0
# 323266    2023-09-26           ZW  Zimbabwe       AFRO          0
# 323267    2023-09-27           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 323258            265748           0               5718
# 323259            265748           0               5718
# 323260            265748           0               5718
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323268 entries, 0 to 323267
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      323268 non-null  object
#  1   Country_code       321904 non-null  object
#  2   Country            323268 non-null  object
#  3   WHO_region         323268 non-null  object
#  4   New_cases          323268 non-null  int64
#  5   Cumulative_cases   323268 non-null  int64
#  6   New_deaths         323268 non-null  int64
#  7   Cumulative_deaths  323268 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 19.7+ MB

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 323263    False
# 323264    False
# 323265    False
# 323266    False
# 323267    False
# Length: 323268, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#         Date_reported  Country_code  Country  WHO_region  New_cases  \
# 0               False         False    False       False      False
# 1               False         False    False       False      False
# 2               False         False    False       False      False
# 3               False         False    False       False      False
# 4               False         False    False       False      False
# ...               ...           ...      ...         ...        ...
# 323263          False         False    False       False      False
# 323264          False         False    False       False      False
# 323265          False         False    False       False      False
# 323266          False         False    False       False      False
# 323267          False         False    False       False      False
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                  False       False              False
# ...

# %%
df.isnull().sum()
# Out:
# Date_reported           0
# Country_code         1364
# Country                 0
# WHO_region              0
# New_cases               0
# Cumulative_cases        0
# New_deaths              0
# Cumulative_deaths       0
# dtype: int64

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  3.232680e+05      3.232680e+05  323268.000000       3.232680e+05
# mean   2.384633e+03      1.472605e+06      21.528008       1.805220e+04
# std    3.920838e+04      6.720642e+06     149.018945       7.566745e+04
# min   -6.507900e+04      0.000000e+00   -3520.000000       0.000000e+00
# 25%    0.000000e+00      2.411000e+03       0.000000       1.800000e+01
# 50%    0.000000e+00      3.595300e+04       0.000000       3.940000e+02
# 75%    1.590000e+02      4.154055e+05       2.000000       5.740000e+03
# max    6.966046e+06      1.034368e+08   11447.000000       1.127152e+06

# %%
df.shape
# Out:
# (323268, 8)

# %%
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.drop(columns=['Cumulative_cases','Cumulative_deaths'],inplace=True)

# %%
df["New_cases"]=df["New_cases"].astype("int")
df["New_deaths"]=df["New_deaths"].astype("int")

# %%
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'New_deaths'],
#       dtype='object')

# %%
new_df=df.groupby(["Country","WHO_region"])[["New_cases", "New_deaths"]].sum()

# %%
new_df
# Out:
#                                                                New_cases  \
# Country                                            WHO_region
# Afghanistan                                        EMRO           225983
# Albania                                            EURO           334090
# Algeria                                            AFRO           271852
# American Samoa                                     WPRO             8341
# Andorra                                            EURO            48015
# ...                                                                  ...
# Wallis and Futuna                                  WPRO             3550
# Yemen                                              EMRO            11945
# Zambia                                             AFRO           349287
# Zimbabwe                                           AFRO           265748
# occupied Palestinian territory, including east ... EMRO           703228
#
# ...

# %%
country_cases=new_df.groupby("Country")["New_cases"].sum()
country_cases=country_cases.sort_values(ascending=False).head(20)

# %%
country_cases
# Out:
# Country
# United States of America      103436829
# China                          99311610
# India                          44998525
# France                         38997490
# Germany                        38437756
# Brazil                         37720419
# Republic of Korea              34571873
# Japan                          33803572
# Italy                          26007789
# The United Kingdom             24715857
# Russian Federation             23014969
# Türkiye                        17004677
# Spain                          13980340
# Viet Nam                       11623571
# Australia                      11600795
# Argentina                      10054576
# Netherlands                     8617412
# Mexico                          7686132
# Iran (Islamic Republic of)      7616791
# Indonesia                       6813429
# Name: New_cases, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=country_cases.index,y=country_cases.values,palette="cividis")

plt.title('Top 50 Countries - Total Number of New Cases')
plt.xlabel('Countrys')
plt.ylabel('Total Number of New Cases')  # y-ekseni etiketi
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}')) #Prints the values in the graph as integers
plt.show()
# Out:
# <ipython-input-50-5c5f65b96bc6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_cases.index,y=country_cases.values,palette="cividis")

# %%
country_deaths=new_df.groupby("Country")["New_deaths"].sum()
country_deaths=country_deaths.sort_values(ascending=False).head(20)

# %%
country_deaths
# Out:
# Country
# United States of America      1127152
# Brazil                         704659
# India                          532031
# Russian Federation             400023
# Mexico                         334586
# The United Kingdom             229307
# Peru                           221465
# Italy                          191469
# Germany                        174979
# France                         167985
# Indonesia                      161918
# Iran (Islamic Republic of)     146386
# Colombia                       142977
# Argentina                      130472
# Spain                          121852
# China                          121714
# Poland                         119644
# Ukraine                        109904
# South Africa                   102595
# Türkiye                        101419
# Name: New_deaths, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=country_deaths.index,y=country_deaths.values)
plt.title('Top 50 Countries - Total Number of New Deaths')
plt.xlabel('Countrys')
plt.ylabel('Total Number of New Deaths')
plt.xticks(rotation=90)
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}')) #Prints the values in the graph as integers
plt.show()

# %%
region_cases=df.groupby("WHO_region")["New_cases"].sum().sort_values(ascending=False)

# %%
region_cases
# Out:
# WHO_region
# EURO     276134635
# WPRO     207284734
# AMRO     193286267
# SEARO     61205037
# EMRO      23394122
# AFRO       9569874
# Other          764
# Name: New_cases, dtype: int64

# %%
plt.figure(figsize=(15, 7))
plt.pie(region_cases.values, labels=region_cases.index, autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Drawing a white circle in the center, making it hollow
plt.title('Total Number of New Cases by Region')
plt.show()

# %%
region_deaths=df.groupby("WHO_region")["New_deaths"].sum()
region_deaths=region_deaths.sort_values(ascending=False)

# %%
region_deaths
# Out:
# WHO_region
# AMRO     2959269
# EURO     2248608
# SEARO     806781
# WPRO      417745
# EMRO      351465
# AFRO      175435
# Other         13
# Name: New_deaths, dtype: int64

# %%
plt.figure(figsize=(15, 7))
plt.pie(region_deaths.values, labels=region_deaths.index, autopct='%1.1f%%', startangle=0, pctdistance=0.85)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Drawing a white circle in the center, making it hollow
plt.title('Total Number of New Deaths by Region')
plt.show()

# %%
new_df['Death_rate'] = (new_df['New_deaths'] / new_df['New_cases']) * 100

# %%
new_df2=new_df['Death_rate'].sort_values(ascending=False).head(70)

# %%
new_df2
# Out:
# Country                           WHO_region
# Yemen                             EMRO          18.074508
# Sudan                             EMRO           7.885237
# Syrian Arab Republic              EMRO           5.508246
# Somalia                           EMRO           4.979147
# Peru                              AMRO           4.900696
#                                                   ...
# Mauritania                        AFRO           1.563750
# Congo                             AFRO           1.543896
# Nicaragua                         AMRO           1.527622
# Ethiopia                          AFRO           1.511595
# Democratic Republic of the Congo  AFRO           1.485379
# Name: Death_rate, Length: 70, dtype: float64

# %%
countries = new_df2.index.get_level_values(0)

# %%
region_rate=new_df2.groupby("WHO_region").sum().sort_values(ascending=False)

# %%
region_rate
# Out:
# WHO_region
# AFRO     57.827292
# EMRO     51.188006
# AMRO     43.260355
# EURO     23.524456
# SEARO     7.926450
# WPRO      3.821096
# Other     1.701571
# Name: Death_rate, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.bar(region_rate.index, region_rate.values, color="pink")
plt.title('Deaths rates of regions by number of cases (%)')
plt.xlabel('Regions')
plt.ylabel('Deaths Rate (%)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
vacc=pd.read_csv("/content/WHO-COVID-19-global-data[1].csv")

# %%
vacc
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 323263    2023-09-23           ZW     Zimbabwe       AFRO          0
# 323264    2023-09-24           ZW     Zimbabwe       AFRO          0
# 323265    2023-09-25           ZW     Zimbabwe       AFRO          0
# 323266    2023-09-26           ZW     Zimbabwe       AFRO          0
# 323267    2023-09-27           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...
